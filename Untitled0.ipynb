# %% [markdown]
# ## 구글드라이브 설정

# %%
# %cd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /root
# Mounted at /content/gdrive

# %% [markdown]
# ## /content/gdrive/MyDrive/를 /mydrive로 대체하기 위해

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive

# %% [markdown]
# ## yolov5 폴더롤 이동 후 yolov5 다운로드 및 환경 설정을 위한 프로그램 설치(requirements.txt 파일)

# %%
# %cd /mydrive/yolov5
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# /content/gdrive/MyDrive/yolov5

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch.git  # clone repo
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.0+cu118 (Tesla T4)

# %%
# !python track.py --yolo-weights /content/gdrive/MyDrive/yolov5/yolov5/runs/train/yolov5_FS_det5/weights/best.pt --source /content/gdrive/MyDrive/yolov5/test_boar_video.mp4 --save-vid
# Out:
# track: yolo_weights=[PosixPath('/content/gdrive/MyDrive/yolov5/yolov5/runs/train/yolov5_FS_det5/weights/best.pt')], reid_weights=/content/gdrive/MyDrive/yolov5/weights/osnet_x0_25_msmt17.pt, tracking_method=strongsort, source=/content/gdrive/MyDrive/yolov5/test_boar_video.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1
# Expected end or semicolon (after name and no valid version specifier)
#     git+https://github.com/samson-wang/cython_bbox.git@9badb346a9222c98f828ba45c63fe3b7f2790ea2
#        ^
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# ...

# %%
# %cd yolov5
# Out:
# /content/gdrive/MyDrive/yolov5/yolov5

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.0+cu118 (Tesla T4)

# %%
# %pip install -qr requirements.txt # install dependencies
# !unzip /mydrive/yolov5/yolov5/total_images.zip -d datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.0 MB/s eta 0:00:00

# %%
# !python train.py --batch 12 --epochs 128 --data /content/gdrive/MyDrive/yolov5/yolov5/data/wildboar.yaml --cfg /content/gdrive/MyDrive/yolov5/yolov5/models/yolov5s_wildboar.yaml --name new --weights /content/gdrive/MyDrive/yolov5/yolov5/yolov5s.pt
# Out:
# train: weights=/content/gdrive/MyDrive/yolov5/yolov5/yolov5s.pt, cfg=/content/gdrive/MyDrive/yolov5/yolov5/models/yolov5s_wildboar.yaml, data=/content/gdrive/MyDrive/yolov5/yolov5/data/wildboar.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=128, batch_size=12, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=new, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# Expected end or semicolon (after name and no valid version specifier)
# ...

# %%
# !python detect.py --source /content/gdrive/MyDrive/yolov5/yolov5/datasets/back_test/ --img 416 --conf 0.3 --weights /content/gdrive/MyDrive/yolov5/yolov5/runs/train/new/weights/best.pt --save-txt
# Out:
# detect: weights=['/content/gdrive/MyDrive/yolov5/yolov5/runs/train/new/weights/best.pt'], source=/content/gdrive/MyDrive/yolov5/yolov5/datasets/back_test/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# Expected end or semicolon (after name and no valid version specifier)
#     git+https://github.com/samson-wang/cython_bbox.git@9badb346a9222c98f828ba45c63fe3b7f2790ea2
#        ^
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s_wildboar summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# ...
